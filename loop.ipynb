# %%
total = sum(number for number in range (101) if number%2 != 0)
print(total)
# Out:
# 2500

# %%
total = 0
num = 1
while num <= 100:
    total += num
    num += 2
    
print(total)
# Out:
# 2500

# %%
total = 0
for i in range(1, 100, 2):
    total += i
print(total)
# Out:
# 2500
