# %%
var = "James" 2 3
print(var)
# Out:
#   Cell In[1], line 1
#     var = "James" 2 3
#                   ^
# SyntaxError: invalid syntax

# %%
x = 10

y = 50

if x ** 2 > 100 and y < 100:
    print(x)
else:
    print('none')
# Out:
# none

# %%
print(2%6)
# Out:
# 2

# %%
print(2**2**2)
# Out:
# 16

# %%
x = 5

y = 10

if x > 0 or y < 5:

    print("Condition met")

else:

    print("Condition not met")
# Out:
# Condition met

# %%
val1 = 7

val2 = 3

print(val1 // val2)
# Out:
# 2

# %%
a = "Python"

print(a[2:5])
# Out:
# tho
